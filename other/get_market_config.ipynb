# %%
from synthetix_v3.market_base import TestMarketBase

# %%
market_base = TestMarketBase()

# %%
market_configs = market_base.get_market_configurations()  # market identification info

# %%
markets = market_base.get_markets()  # market contract addresses

# %%
markets
# Out:
#   markets_id                             markets_address  markets_created_at  \
# 0          1  0x17633a63083dbd4941891f87bdf31b896e91e2b9          1693681020
# 1          2  0x17633a63083dbd4941891f87bdf31b896e91e2b9          1693681026
# 2          3  0x17633a63083dbd4941891f87bdf31b896e91e2b9          1693681032
# 3          4  0x17633a63083dbd4941891f87bdf31b896e91e2b9          1693681036
# 4          5  0x17633a63083dbd4941891f87bdf31b896e91e2b9          1693681046
# 5          6  0x9863dae3f4b5f4ffe3a841a21565d57f2ba10e87          1693681144
#
#    markets_created_at_block  markets_updated_at  markets_updated_at_block  \
# 0                   9243702          1697124898                  10965641
# 1                   9243705          1697714544                  11260464
# 2                   9243708          1697124898                  10965641
# 3                   9243710          1696937944                  10872164
# ...
