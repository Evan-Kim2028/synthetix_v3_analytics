# %%
from synthetix_v3.base_perps import BasePerps
import polars as pl

# %%
base_perp = BasePerps()

# %%
markets_df = base_perp.get_markets()

# %%
markets_df
# Out:
#   markets_id  markets_perpsMarketId       markets_marketName  \
# 0        100                    100                 Ethereum
# 1        200                    200                  Bitcoin
# 2        300                    300          Chainlink Token
# 3        400                    400           Optimism Token
# 4        500                    500  Synthetix Network Token
#
#   markets_marketSymbol            markets_price              markets_skew  \
# 0                  ETH   1605755239520000000000     751434479408414482738
# 1                  BTC  29484328865790000000000    -119758645168273550429
# 2                 LINK      7601531700000000000   12377142756607663116044
# 3                   OP      1230084960000000000  -38703373500000000000000
# 4                  SNX      1965150500000000000  105914960820381441226014
#
#                markets_size         markets_sizeDelta  \
# 0   10766484496454434010602         62200000000000000
# ...

# %%
markets_df.columns
# Out:
# Index(['markets_id', 'markets_perpsMarketId', 'markets_marketName',
#        'markets_marketSymbol', 'markets_price', 'markets_skew', 'markets_size',
#        'markets_sizeDelta', 'markets_currentFundingRate',
#        'markets_currentFundingVelocity', 'markets_feedId',
#        'markets_maxFundingVelocity', 'markets_skewScale',
#        'markets_lockedOiPercent', 'markets_marketOwner', 'markets_owner',
#        'markets_initialMarginRatioD18', 'markets_maintenanceMarginRatioD18',
#        'markets_liquidationRewardRatioD18',
#        'markets_maxSecondsInLiquidationWindow',
#        'markets_minimumPositionMargin',
#        'markets_maxLiquidationLimitAccumulationMultiplier', 'markets_makerFee',
#        'markets_takerFee', 'markets_factoryInitialized'],
#       dtype='object')
